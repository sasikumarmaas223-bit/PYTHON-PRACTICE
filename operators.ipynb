# %%
print("welcome")
# Out:
# welcome

# %%
print("thikkal sameera")
# Out:
# thikkal sameera

# %%
# 1.creat a variable name and store your name.
name="Sasikumar"
print(name)
# Out:
# Sasikumar

# %%
#2. store your age.
age=20
print(age)
# Out:
# 20

# %%
#3. store your college name.
college_name="Mother theresa institute of engineering and technology"
print(college_name)
# Out:
# Mother theresa institute of engineering and technology

# %%
# 4. store your favorite colour.
my_favorite_color="BLUE"
print(my_favorite_color)
# Out:
# BLUE

# %%
# 5. print all four variables.
name="Sasikumar"
age=20
college_name="MTIEAT"
fav_col="BLUE"
print(name)
print(age)
print(college_name)
print(fav_col)
# Out:
# Sasikumar
# 20
# MTIEAT
# BLUE

# %%
# 6. create two variables a=10,b=20 and print them.
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
# 7. change a to 100 and print it.
a=10
a=100
print(a)
# Out:
# 100

# %%
# 8. create three variables in one line.
a=b=c=100
print(a,b,c)
# 9. store the same value 50 in three variables.
a=b=c=50
print(a,b,c)
# Out:
# 100 100 100
# 50 50 50

# %%
# 10. create a variable city and print I Live In Ananthapur.
city="I Live In Ananthapur."
print(city)
# Out:
# I Live In Ananthapur.

# %%
# 11 . store your height
# 12 . store your weight 
# 13 . print My height is
height=5.5
weight=55
print("My height is",height)
# Out:
# My height is 5.5

# %%
# 14 . swap 2 variables.
a=14
b=25
a,b=b,a
print(a)
print(b)
# Out:
# 25
# 14

# %%
# 15 . create variables student_name, roll_number and branch and print them.
student_name="Sasikumar"
roll_number="23HR1A0591"
branch=("CSE")
print(student_name)
print(roll_number)
print(branch)
# Out:
# Sasikumar
# 23HR1A0591
# CSE

# %%
# 16. create five variables for a student profile and print them.
name="Sasikumar"
roll_number=591
branch="CSE"
section="B"
college_name="MTIEAT"
print(name)
print(roll_number)
print(branch)
print(section)
print(college_name)
# Out:
# Sasikumar
# 591
# CSE
# B
# MTIEAT

# %%
# 17. create variables for two products and their prices and print them.
product1="chicken masala"
product1_price="10rs."
product2="mutton masala"
product2_price="20rs."
print(product1,product1_price)
print(product2,product2_price)
# Out:
# chicken masala 10rs.
# mutton masala 20rs.

# %%
# 18. store today's year in a variable and print it.
year=2026
print(year)
# Out:
# 2026

# %%
# 19. create variables x,y,z in one line and print their sum.
x=10
y=20
z=30
sum=x+y+z
print(sum)
# Out:
# 60

# %%
# 20. write a program using only variables to display your basic profile(name, age, city, college, branch)
name="R.Sasikumar"
age=20
city="chittoor"
college="MTIEAT"
branch=("CSE")
print(name)
print(age)
print(city)
print(college)
print(branch)
# Out:
# R.Sasikumar
# 20
# chittoor
# MTIEAT
# CSE

# %%
# 21. create an integer variable and print it.
int=20
print(int)
# Out:
# 20

# %%
# 22. create a float variable and print it.
height=5.9
print(height)
# Out:
# 5.9

# %%
# 23. create a string variable and print it.
name="R.Sasikumar"
print(name)
# Out:
# R.Sasikumar

# %%
# 24. create a boolean varible.
is_student=True
is_not_student=False
print(is_student)
print(is_not_student)
# Out:
# True
# False

# %%
# 25. print type of an integer.
age=20
print(type(age))
# Out:
# <class 'int'>

# %%
# 26. print type of a float.
height=5.9
print(type(height))
# Out:
# <class 'float'>

# %%
# 27. print type of a string.
name="R.Sasikumar"
print(type(name))
# Out:
# <class 'str'>

# %%
# 28. convert the string "250" to an integer.
num="250"
print(int(num))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 # 28. convert the string "250" to an integer.
#       2 num="250"
# ----> 3 print(int(num))
#       4
#
# TypeError: 'int' object is not callable

# %%
# 29. Create five variables of different data types and print their types.
age=20
height=5.9
name="sasi"
is_student=True
x=2+3j
print(type(age))
print(type(height))
print(type(name))
print(type(is_not_student))
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# 30. Store your name, age, CGPA, and student status using appropriate data types.
name="R.Sasikumar"
age=20
CGPA=70.9
is_student=True
# 31. Print the data type of each variable.
print(type(name))
print(type(age))
print(type(CGPA))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#32. Convert "500" into an integer and add 100.
num="500"
b=100
add=int(num)+b
print(add)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       1 #32. Convert "500" into an integer and add 100.
#       2 num="500"
#       3 b=100
# ----> 4 add=int(num)+b
#       5 print(add)
#
# TypeError: 'int' object is not callable

# %%
# 33.Convert an integer to a float.
num=91
print(float(num))
# Out:
# 91.0

# %%
# 34. Convert a float to an integer.
num=91.0
print(int(num))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 # 34. Convert a float to an integer.
#       2 num=91.0
# ----> 3 print(int(num))
#
# TypeError: 'int' object is not callable

# %%
# 35. Create five variables of different data types and print their types.
# 29. Create five variables of different data types and print their types.
age=20
height=5.9
name="sasi"
is_student=True
x=2+3j
print(type(age))
print(type(height))
print(type(name))
print(type(is_not_student))
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# 36. Create a boolean variable.
is_student=True
#   37. Print the type of a boolean.
print(type(is_student))
# Out:
# <class 'bool'>

# %%
#38. Create a complex number.
x=2+7j
#39. Print the type of a complex.
print(type(x))
# Out:
# <class 'complex'>
