# %%
n=18
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
# 1. Check if a person is 18 or older, then check if they have a driving licence.
age=18
if age >= 18:
    print("eligible")
else:
    print("not eligible")
# Out:
# eligible for vote

# %%
# 2. Check if marks are at least 35, then check if marks are at least 75.
marks=50
if marks>=35:
    print("pass")
    if marks>=75:
        print("topper")
        if marks<35:
            print("fail")
# Out:
# pass

# %%
# 3. Check if a number is positive, then check if it is even.
num=10
if num>0:
    print("positive")
    if num<0:
        print("negative")
    elif num%2==0:
        print("even number")
    else:
        print("odd number")
# Out:
# positive
# even number

# %%
# 4. Check if a student is present, then check if they submitted homework.
