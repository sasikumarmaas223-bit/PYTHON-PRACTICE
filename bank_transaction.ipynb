# %%
balance=155000
min_balance=500
print("before transaction:",balance)
while min_balance<balance:
    balance=balance-1900
    
    print("after transaction :",balance)

# %%
balance=155000
min_balance=500
print("before transaction:",balance)
while min_balance<balance:
    balance=balance-1900
    
    print("after transaction :",balance)
# Out:
# before transaction: 155000
# after transaction : 153100
# after transaction : 151200
# after transaction : 149300
# after transaction : 147400
# after transaction : 145500
# after transaction : 143600
# after transaction : 141700
# after transaction : 139800
# after transaction : 137900
# after transaction : 136000
# after transaction : 134100
# after transaction : 132200
# after transaction : 130300
# after transaction : 128400
# after transaction : 126500
# after transaction : 124600
# after transaction : 122700
# after transaction : 120800
# after transaction : 118900
# after transaction : 117000
# after transaction : 115100
# after transaction : 113200
# after transaction : 111300
# after transaction : 109400
# after transaction : 107500
# after transaction : 105600
# after transaction : 103700
# after transaction : 101800
# after transaction : 99900
# after transaction : 98000
# after transaction : 96100
# after transaction : 94200
# after transaction : 92300
# after transaction : 90400
# after transaction : 88500
# after transaction : 86600
# after transaction : 84700
# after transaction : 82800
# after transaction : 80900
# after transaction : 79000
# after transaction : 77100
# after transaction : 75200
# after transaction : 73300
# after transaction : 71400
# after transaction : 69500
# after transaction : 67600
# after transaction : 65700
# after transaction : 63800
# after transaction : 61900
# after transaction : 60000
# after transaction : 58100
# after transaction : 56200
# after transaction : 54300
# after transaction : 52400
# after transaction : 50500
# after transaction : 48600
# after transaction : 46700
# after transaction : 44800
# after transaction : 42900
# after transaction : 41000
# after transaction : 39100
# after transaction : 37200
# after transaction : 35300
# after transaction : 33400
# after transaction : 31500
# after transaction : 29600
# after transaction : 27700
# after transaction : 25800
# after transaction : 23900
# after transaction : 22000
# after transaction : 20100
# after transaction : 18200
# after transaction : 16300
# after transaction : 14400
# after transaction : 12500
# after transaction : 10600
# after transaction : 8700
# after transaction : 6800
# after transaction : 4900
# after transaction : 3000
# after transaction : 1100
# after transaction : -800
